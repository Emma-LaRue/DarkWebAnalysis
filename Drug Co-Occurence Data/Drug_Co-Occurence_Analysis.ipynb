# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import compress

import datetime
import calendar
from dateutil.parser import parse
from matplotlib import rc

import math
import os
import copy
import pickle

import itertools
import operator

# %%
# Read in data (from pickle file)
file = open('drug_data','rb')
drug_data = pickle.load(file)

# %%
drug_data.tail()
# Out:
#        transaction_id  vendor_id  vendor_name bitcoin    USD  \
# 119927        '121025       2031  SweetTreats       0   61.0
# 119928        '121026       2031  SweetTreats       0   78.0
# 119929        '121027       2031  SweetTreats       0   61.0
# 119930        '121028       2031  SweetTreats       0  112.0
# 119932        '121030       2306     majordan       0   -1.0
#
#                                       product_description                date  \
# 119927  3 Piece - 61 USD - HOLIDAY SALE 17/EA | Distil... 2019-01-01 09:40:00
# 119928  4 Piece - 78 USD - HOLIDAY SALE 17/EA | Distil... 2018-12-31 12:22:00
# 119929  3 Piece - 61 USD - HOLIDAY SALE 17/EA | Distil... 2018-12-30 11:09:00
# 119930  6 Piece - 112 USD - HOLIDAY SALE 17/EA | Disti... 2018-12-29 08:53:00
# 119932    1 Piece - 240 EUR - 1 bar of hublot pollen hash 2018-12-28 04:38:00
#
#        drug_prediction  rating  \
# 119927     [marijuana]     5.0
# 119928     [marijuana]     5.0
# 119929     [marijuana]     4.0
# 119930     [marijuana]     5.0
# 119932       [hashish]     5.0
#
#                                                  feedback  market_id  \
# 119927                        great carts will buy again!          2
# 119928                        great carts will buy again!          2
# 119929                        great carts will buy again!          2
# 119930  Great value, good quality, quick shipping -- t...          2
# 119932                                              #####          2
#
#        buyer_name  drug_cats
# 119927      S***0  marijuana
# 119928      c***9  marijuana
# 119929      c***9  marijuana
# 119930      s***r  marijuana
# 119932      b***w    hashish

# %% [markdown]
# ## Get all the unique drugs for each vendor

# %%
#Get all the unique buyer names 
_ , unique_buyers = pd.factorize(drug_data['buyer_name'])

# %%
unique_buyers
# Out:
# Index(['P*****d', 'B*****u', 'z*****d', 'b*****4', 'K*****z', 'M*****h',
#        'G*****4', 't*****1', 'w*****y', 'D*****5',
#        ...
#        'zrc5004', 'level', 'terrybones', 'hoho76', 'P***y', 'B***3', 'z***c',
#        'j***g', 'T***o', 'g***3'],
#       dtype='object', length=4400)

# %%
#Get dataframe with buyer names, market id, drug prediction
buyer_and_drug = copy.deepcopy(drug_data.iloc[:,[10,11,5,7]])

buyer_and_drug.columns = ['market_id','buyer_name','product_description','drug_prediction']

# %%
buyer_and_drug.tail()
# Out:
#         market_id buyer_name  \
# 119927          2      S***0
# 119928          2      c***9
# 119929          2      c***9
# 119930          2      s***r
# 119932          2      b***w
#
#                                       product_description drug_prediction
# 119927  3 Piece - 61 USD - HOLIDAY SALE 17/EA | Distil...     [marijuana]
# 119928  4 Piece - 78 USD - HOLIDAY SALE 17/EA | Distil...     [marijuana]
# 119929  3 Piece - 61 USD - HOLIDAY SALE 17/EA | Distil...     [marijuana]
# 119930  6 Piece - 112 USD - HOLIDAY SALE 17/EA | Disti...     [marijuana]
# 119932    1 Piece - 240 EUR - 1 bar of hublot pollen hash       [hashish]

# %%
#function to convert list to string
def flatten(drug_list):
    str1 = ''.join(drug_list)
    return str1

#convert predictions from list to strings
buyer_and_drug['drug_cats'] = buyer_and_drug.iloc[:,3].apply(flatten)

# %%
buyer_and_drug.head()
# Out:
#    market_id buyer_name                                product_description  \
# 0          3    P*****d  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 1          3    B*****u  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 2          3    z*****d  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 3          3    b*****4  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 4          3    K*****z  ? MDMA very high QUALITY 87%?The Best MDMA for...
#
#   drug_prediction drug_cats
# 0       [ecstasy]   ecstasy
# 1       [ecstasy]   ecstasy
# 2       [ecstasy]   ecstasy
# 3       [ecstasy]   ecstasy
# 4       [ecstasy]   ecstasy

# %%
#Define a function to get all drug types for each buyer_name
def getDrugForBuyer(buyer):
    
    buyer_subset = buyer_and_drug[buyer_and_drug['buyer_name'] == buyer]

    drug_pred_list = list(buyer_subset['drug_cats'])
    
    return drug_pred_list

# %%
#Create a dataframe with all the unique buyer names
buyer_df = pd.DataFrame(unique_buyers)
buyer_df.columns = ['buyer_name']

# %%
#Get all the list of drugs predictions for each vendor
drug_lists = []

for buyer in unique_buyers:
    buy = getDrugForBuyer(buyer)
    drug_lists.append(buy)

# %%
#fill dataframe with drug_prediction for each buyer
buyer_df['list_of_drugs'] = drug_lists

# %%
buyer_df.head()
# Out:
#   buyer_name                                      list_of_drugs
# 0    P*****d  [ecstasy, ecstasy, lsd, ecstasy, ecstasy, hero...
# 1    B*****u  [ecstasy, methamphetamine, methamphetamine, me...
# 2    z*****d  [ecstasy, ecstasy, ecstasy, ecstasy, ecstasy, ...
# 3    b*****4  [ecstasy, ecstasy, not_drugs, not_drugs, not_d...
# 4    K*****z                                 [ecstasy, ecstasy]

# %%
def getUniqueDrug(drug_list):
    unique_drugs = list(set(drug_list))
    
    return unique_drugs

# %%
#Get all the unique drugs for each buyer
buyer_df['unique_drug_predictions'] = buyer_df.iloc[:,1].apply(getUniqueDrug)

# %%
buyer_df.head()
# Out:
#   buyer_name                                      list_of_drugs  \
# 0    P*****d  [ecstasy, ecstasy, lsd, ecstasy, ecstasy, hero...
# 1    B*****u  [ecstasy, methamphetamine, methamphetamine, me...
# 2    z*****d  [ecstasy, ecstasy, ecstasy, ecstasy, ecstasy, ...
# 3    b*****4  [ecstasy, ecstasy, not_drugs, not_drugs, not_d...
# 4    K*****z                                 [ecstasy, ecstasy]
#
#                              unique_drug_predictions
# 0                  [lsd, ecstasy, not_drugs, heroin]
# 1  [ecstasy, marijuana, psychedelic, lsd, methamp...
# 2                                 [ecstasy, hashish]
# 3                               [ecstasy, not_drugs]
# 4                                          [ecstasy]

# %%
#Define a function to get all the market ids for each buyer
def getMarketOfBuyer(buyer):
    
    buyer_subset = buyer_and_drug[buyer_and_drug['buyer_name'] == buyer]

    market_id_list = list(buyer_subset['market_id'])
    
    return market_id_list

# %%
#Get all the list of market ids for each buyer
market_list = []

for buyer in unique_buyers:
    market_number = getMarketOfBuyer(buyer)
    market_list.append(market_number)

# %%
#fill dataframe with market ids for each buyer
buyer_df['market_number'] = market_list

# %%
def getUniqueMarket(m_list):
    unique_markets = list(set(m_list))
    
    return unique_markets

# %%
buyer_df.head()
# Out:
#   buyer_name                                      list_of_drugs  \
# 0    P*****d  [ecstasy, ecstasy, lsd, ecstasy, ecstasy, hero...
# 1    B*****u  [ecstasy, methamphetamine, methamphetamine, me...
# 2    z*****d  [ecstasy, ecstasy, ecstasy, ecstasy, ecstasy, ...
# 3    b*****4  [ecstasy, ecstasy, not_drugs, not_drugs, not_d...
# 4    K*****z                                 [ecstasy, ecstasy]
#
#                              unique_drug_predictions  \
# 0                  [lsd, ecstasy, not_drugs, heroin]
# 1  [ecstasy, marijuana, psychedelic, lsd, methamp...
# 2                                 [ecstasy, hashish]
# 3                               [ecstasy, not_drugs]
# 4                                          [ecstasy]
#
#                                        market_number
# 0  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 1  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 2      [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 3  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 4                                             [3, 3]

# %%
#Get all the unique drugs for each buyer
buyer_df['unique_market'] = buyer_df.iloc[:,3].apply(getUniqueMarket)

# %%
buyer_df.head()
# Out:
#   buyer_name                                      list_of_drugs  \
# 0    P*****d  [ecstasy, ecstasy, lsd, ecstasy, ecstasy, hero...
# 1    B*****u  [ecstasy, methamphetamine, methamphetamine, me...
# 2    z*****d  [ecstasy, ecstasy, ecstasy, ecstasy, ecstasy, ...
# 3    b*****4  [ecstasy, ecstasy, not_drugs, not_drugs, not_d...
# 4    K*****z                                 [ecstasy, ecstasy]
#
#                              unique_drug_predictions  \
# 0                  [lsd, ecstasy, not_drugs, heroin]
# 1  [ecstasy, marijuana, psychedelic, lsd, methamp...
# 2                                 [ecstasy, hashish]
# 3                               [ecstasy, not_drugs]
# 4                                          [ecstasy]
#
#                                        market_number unique_market
# 0  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...           [3]
# 1  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...           [3]
# 2      [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]           [3]
# 3  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...           [3]
# 4                                             [3, 3]           [3]

# %%
# buyer_df.to_csv(r'buyer_df.csv', index = False)

# %% [markdown]
# ## Check for relation in buyer name and buying habits

# %%
#Get the first and last letter for each buyer
def getCharacters(vendor_name):
    first_letter = vendor_name[0]
    last_letter = vendor_name[-1]
    
    return first_letter + last_letter

# %%
#Get all the first and last letters of each buyer
buyer_df['buyer_ID'] = buyer_df.iloc[:,0].apply(getCharacters)

# %%
len(buyer_df)
# Out:
# 4400

# %%
#Make copy of dataframe with just buyer id and unique purchases
id_drug_df = copy.deepcopy(buyer_df.iloc[:,[5,2]])

id_drug_df.columns = ['Buyer_ID', 'Unique_Buys']

# %%
id_drug_df = id_drug_df.sort_values(by=['Buyer_ID'])

# %%
id_drug_df.to_csv(r'id_drug.csv', index = False)

# %% [markdown]
# ### Note: did not see many similarities

# %% [markdown]
# ## Investigate Drug Co-Occurence

# %%
#Get the list unique drugs for each buyer
drug_series = buyer_df['unique_drug_predictions'].tolist()

# %%
from collections import Counter
from itertools import combinations

counter  = Counter()

# %%
#find the most common pairings of each list
for sub in drug_series:
    if len(drug_series) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        counter[comb] += 1

# %%
#Print the most common pairings
most_common = counter.most_common()

most_common
# Out:
# [(('cocaine', 'marijuana'), 256),
#  (('marijuana', 'not_drugs'), 246),
#  (('', 'not_drugs'), 222),
#  (('ecstasy', 'marijuana'), 221),
#  (('', 'marijuana'), 199),
#  (('cocaine', 'ecstasy'), 197),
#  (('marijuana', 'methamphetamine'), 166),
#  (('ecstasy', 'not_drugs'), 163),
#  (('hashish', 'marijuana'), 140),
#  (('cocaine', 'methamphetamine'), 138),
#  (('', 'ecstasy'), 135),
#  (('lsd', 'not_drugs'), 127),
#  (('cocaine', 'not_drugs'), 124),
#  (('', 'cocaine'), 122),
#  (('ecstasy', 'methamphetamine'), 117),
#  (('lsd', 'marijuana'), 117),
#  (('ecstasy', 'lsd'), 107),
#  (('benzodiazepines', 'marijuana'), 102),
#  (('ecstasy', 'ketamine'), 91),
#  (('cocaine', 'hashish'), 83),
#  (('', 'methamphetamine'), 81),
#  (('marijuana', 'psilocybin'), 81),
#  (('benzodiazepines', 'cocaine'), 80),
#  (('methamphetamine', 'not_drugs'), 79),
#  (('cocaine', 'lsd'), 79),
#  (('ketamine', 'marijuana'), 75),
#  (('marijuana', 'stimulant'), 74),
#  (('', 'lsd'), 73),
#  (('cocaine', 'ketamine'), 73),
#  (('benzodiazepines', 'ecstasy'), 72),
#  (('ecstasy', 'hashish'), 61),
#  (('heroin', 'marijuana'), 61),
#  (('ecstasy', 'stimulant'), 58),
#  (('hashish', 'not_drugs'), 58),
#  (('ecstasy', 'psilocybin'), 58),
#  (('marijuana', 'oxycodone'), 57),
#  (('', 'ketamine'), 56),
#  (('benzodiazepines', 'not_drugs'), 54),
#  (('ketamine', 'not_drugs'), 54),
#  (('cocaine', 'heroin'), 54),
#  (('', 'psilocybin'), 54),
#  (('cocaine', 'psilocybin'), 54),
#  (('', 'hashish'), 53),
#  (('cocaine', 'stimulant'), 52),
#  (('', 'benzodiazepines'), 49),
#  (('benzodiazepines', 'methamphetamine'), 49),
#  (('dmt', 'not_drugs'), 48),
#  (('lsd', 'methamphetamine'), 46),
#  (('ketamine', 'lsd'), 45),
#  (('ketamine', 'methamphetamine'), 45),
#  (('heroin', 'methamphetamine'), 43),
#  (('ecstasy', 'heroin'), 42),
#  (('hashish', 'methamphetamine'), 42),
#  (('lsd', 'psilocybin'), 42),
#  (('not_drugs', 'psilocybin'), 40),
#  (('', 'stimulant'), 38),
#  (('heroin', 'not_drugs'), 37),
#  (('cocaine', 'oxycodone'), 37),
#  (('ecstasy', 'psychedelic'), 36),
#  (('not_drugs', 'stimulant'), 36),
#  (('dmt', 'marijuana'), 36),
#  (('methamphetamine', 'stimulant'), 36),
#  (('benzodiazepines', 'lsd'), 34),
#  (('marijuana', 'psychedelic'), 32),
#  (('methamphetamine', 'oxycodone'), 31),
#  (('hashish', 'lsd'), 31),
#  (('ketamine', 'stimulant'), 30),
#  (('methamphetamine', 'psilocybin'), 30),
#  (('cocaine', 'psychedelic'), 29),
#  (('dmt', 'lsd'), 29),
#  (('ecstasy', 'oxycodone'), 29),
#  (('lsd', 'stimulant'), 28),
#  (('', 'oxycodone'), 28),
#  (('marijuana', 'opioid'), 28),
#  (('benzodiazepines', 'stimulant'), 27),
#  (('cocaine', 'erectile_dysfunction'), 27),
#  (('ecstasy', 'erectile_dysfunction'), 26),
#  (('dmt', 'ecstasy'), 26),
#  (('lsd', 'psychedelic'), 25),
#  (('', 'heroin'), 24),
#  (('', 'dmt'), 24),
#  (('benzodiazepines', 'oxycodone'), 24),
#  (('erectile_dysfunction', 'marijuana'), 23),
#  (('benzodiazepines', 'hashish'), 23),
#  (('benzodiazepines', 'ketamine'), 23),
#  (('hashish', 'stimulant'), 23),
#  (('hashish', 'psilocybin'), 22),
#  (('benzodiazepines', 'heroin'), 21),
#  (('not_drugs', 'psychedelic'), 20),
#  (('fentanyl', 'marijuana'), 20),
#  (('heroin', 'lsd'), 19),
#  (('methamphetamine', 'psychedelic'), 19),
#  (('cocaine', 'dmt'), 19),
#  (('benzodiazepines', 'psilocybin'), 19),
#  (('oxycodone', 'psilocybin'), 19),
#  (('hashish', 'ketamine'), 18),
#  (('oxycodone', 'stimulant'), 18),
#  (('not_drugs', 'oxycodone'), 17),
#  (('', 'psychedelic'), 17),
#  (('ketamine', 'psychedelic'), 17),
#  (('psilocybin', 'stimulant'), 17),
#  (('heroin', 'ketamine'), 16),
#  (('erectile_dysfunction', 'methamphetamine'), 15),
#  (('dmt', 'ketamine'), 15),
#  (('lsd', 'oxycodone'), 15),
#  (('cocaine', 'fentanyl'), 15),
#  (('', 'opioid'), 15),
#  (('hashish', 'heroin'), 15),
#  (('benzodiazepines', 'opioid'), 14),
#  (('cocaine', 'opioid'), 14),
#  (('cocaine', 'steroids_and_hormones'), 14),
#  (('erectile_dysfunction', 'lsd'), 13),
#  (('heroin', 'oxycodone'), 13),
#  (('ketamine', 'psilocybin'), 13),
#  (('benzodiazepines', 'psychedelic'), 13),
#  (('marijuana', 'opioid_treatment'), 13),
#  (('ecstasy', 'opioid'), 13),
#  (('dmt', 'psilocybin'), 12),
#  (('methamphetamine', 'opioid_treatment'), 12),
#  (('ecstasy', 'fentanyl'), 11),
#  (('ketamine', 'oxycodone'), 11),
#  (('', 'erectile_dysfunction'), 11),
#  (('benzodiazepines', 'erectile_dysfunction'), 11),
#  (('ecstasy', 'steroids_and_hormones'), 11),
#  (('marijuana', 'steroids_and_hormones'), 11),
#  (('methamphetamine', 'opioid'), 11),
#  (('cocaine', 'opioid_treatment'), 11),
#  (('dmt', 'methamphetamine'), 10),
#  (('psychedelic', 'stimulant'), 10),
#  (('not_drugs', 'opioid'), 10),
#  (('heroin', 'psilocybin'), 10),
#  (('erectile_dysfunction', 'stimulant'), 10),
#  (('cocaine', 'prescription'), 10),
#  (('opioid', 'oxycodone'), 10),
#  (('', 'opioid_treatment'), 10),
#  (('heroin', 'stimulant'), 9),
#  (('dmt', 'psychedelic'), 9),
#  (('fentanyl', 'methamphetamine'), 9),
#  (('erectile_dysfunction', 'oxycodone'), 9),
#  (('dissociative', 'marijuana'), 8),
#  (('inhalants', 'not_drugs'), 8),
#  (('heroin', 'opioid'), 8),
#  (('erectile_dysfunction', 'ketamine'), 8),
#  (('methamphetamine', 'steroids_and_hormones'), 8),
#  (('erectile_dysfunction', 'not_drugs'), 7),
#  (('lsd', 'opioid'), 7),
#  (('dissociative', 'not_drugs'), 7),
#  (('dmt', 'stimulant'), 7),
#  (('ecstasy', 'inhalants'), 7),
#  (('ecstasy', 'prescription'), 7),
#  (('', 'steroids_and_hormones'), 7),
#  (('erectile_dysfunction', 'hashish'), 7),
#  (('marijuana', 'prescription'), 7),
#  (('hashish', 'oxycodone'), 7),
#  (('benzodiazepines', 'dmt'), 6),
#  (('dmt', 'hashish'), 6),
#  (('dissociative', 'ecstasy'), 6),
#  (('dissociative', 'stimulant'), 6),
#  (('dmt', 'heroin'), 6),
#  (('', 'fentanyl'), 6),
#  (('fentanyl', 'hashish'), 6),
#  (('fentanyl', 'lsd'), 6),
#  (('fentanyl', 'not_drugs'), 6),
#  (('psilocybin', 'psychedelic'), 6),
#  (('not_drugs', 'opioid_treatment'), 6),
#  (('ecstasy', 'opioid_treatment'), 6),
#  (('opioid', 'stimulant'), 6),
#  (('dissociative', 'ketamine'), 5),
#  (('fentanyl', 'ketamine'), 5),
#  (('fentanyl', 'stimulant'), 5),
#  (('hashish', 'psychedelic'), 5),
#  (('inhalants', 'marijuana'), 5),
#  (('', 'prescription'), 5),
#  (('benzodiazepines', 'prescription'), 5),
#  (('steroids_and_hormones', 'stimulant'), 5),
#  (('heroin', 'psychedelic'), 5),
#  (('fentanyl', 'oxycodone'), 5),
#  (('benzodiazepines', 'opioid_treatment'), 5),
#  (('erectile_dysfunction', 'psilocybin'), 5),
#  (('fentanyl', 'psilocybin'), 5),
#  (('opioid_treatment', 'oxycodone'), 5),
#  (('', 'dissociative'), 4),
#  (('dissociative', 'lsd'), 4),
#  (('inhalants', 'lsd'), 4),
#  (('inhalants', 'psilocybin'), 4),
#  (('cocaine', 'dissociative'), 4),
#  (('dissociative', 'dmt'), 4),
#  (('dissociative', 'methamphetamine'), 4),
#  (('dmt', 'fentanyl'), 4),
#  (('', 'inhalants'), 4),
#  (('cocaine', 'inhalants'), 4),
#  (('ketamine', 'prescription'), 4),
#  (('benzodiazepines', 'inhalants'), 4),
#  (('inhalants', 'stimulant'), 4),
#  (('fentanyl', 'heroin'), 4),
#  (('ketamine', 'steroids_and_hormones'), 4),
#  (('hashish', 'opioid'), 4),
#  (('benzodiazepines', 'fentanyl'), 4),
#  (('dissociative', 'oxycodone'), 4),
#  (('lsd', 'opioid_treatment'), 4),
#  (('opioid_treatment', 'stimulant'), 4),
#  (('dissociative', 'fentanyl'), 3),
#  (('dissociative', 'hashish'), 3),
#  (('inhalants', 'methamphetamine'), 3),
#  (('benzodiazepines', 'dissociative'), 3),
#  (('inhalants', 'ketamine'), 3),
#  (('erectile_dysfunction', 'opioid'), 3),
#  (('not_drugs', 'steroids_and_hormones'), 3),
#  (('erectile_dysfunction', 'heroin'), 3),
#  (('lsd', 'prescription'), 3),
#  (('prescription', 'psychedelic'), 3),
#  (('erectile_dysfunction', 'psychedelic'), 3),
#  (('ketamine', 'opioid'), 3),
#  (('benzodiazepines', 'steroids_and_hormones'), 3),
#  (('erectile_dysfunction', 'steroids_and_hormones'), 3),
#  (('ecstasy', 'uncategorizable_listing'), 3),
#  (('hashish', 'opioid_treatment'), 3),
#  (('dmt', 'oxycodone'), 3),
#  (('fentanyl', 'opioid'), 3),
#  (('heroin', 'opioid_treatment'), 3),
#  (('ketamine', 'opioid_treatment'), 3),
#  (('methamphetamine', 'prescription'), 3),
#  (('opioid_treatment', 'psilocybin'), 3),
#  (('oxycodone', 'psychedelic'), 3),
#  (('heroin', 'inhalants'), 2),
#  (('dissociative', 'prescription'), 2),
#  (('dmt', 'prescription'), 2),
#  (('not_drugs', 'prescription'), 2),
#  (('prescription', 'stimulant'), 2),
#  (('heroin', 'prescription'), 2),
#  (('opioid', 'prescription'), 2),
#  (('oxycodone', 'prescription'), 2),
#  (('hashish', 'prescription'), 2),
#  (('oxycodone', 'steroids_and_hormones'), 2),
#  (('methamphetamine', 'uncategorizable_listing'), 2),
#  (('stimulant', 'uncategorizable_listing'), 2),
#  (('lsd', 'steroids_and_hormones'), 2),
#  (('cocaine', 'uncategorizable_listing'), 2),
#  (('ketamine', 'uncategorizable_listing'), 2),
#  (('not_drugs', 'uncategorizable_listing'), 2),
#  (('dissociative', 'heroin'), 2),
#  (('dissociative', 'opioid'), 2),
#  (('dissociative', 'opioid_treatment'), 2),
#  (('hashish', 'inhalants'), 2),
#  (('hashish', 'steroids_and_hormones'), 2),
#  (('inhalants', 'psychedelic'), 2),
#  (('inhalants', 'steroids_and_hormones'), 2),
#  (('opioid', 'opioid_treatment'), 2),
#  (('opioid_treatment', 'psychedelic'), 2),
#  (('psilocybin', 'steroids_and_hormones'), 2),
#  (('', 'antidepressant'), 1),
#  (('', 'kratom'), 1),
#  (('', 'uncategorizable_listing'), 1),
#  (('antidepressant', 'benzodiazepines'), 1),
#  (('antidepressant', 'cocaine'), 1),
#  (('antidepressant', 'dissociative'), 1),
#  (('antidepressant', 'dmt'), 1),
#  (('antidepressant', 'ecstasy'), 1),
#  (('antidepressant', 'erectile_dysfunction'), 1),
#  (('antidepressant', 'fentanyl'), 1),
#  (('antidepressant', 'hashish'), 1),
#  (('antidepressant', 'heroin'), 1),
#  (('antidepressant', 'inhalants'), 1),
#  (('antidepressant', 'ketamine'), 1),
#  (('antidepressant', 'kratom'), 1),
#  (('antidepressant', 'lsd'), 1),
#  (('antidepressant', 'marijuana'), 1),
#  (('antidepressant', 'methamphetamine'), 1),
#  (('antidepressant', 'not_drugs'), 1),
#  (('antidepressant', 'opioid'), 1),
#  (('antidepressant', 'opioid_treatment'), 1),
#  (('antidepressant', 'oxycodone'), 1),
#  (('antidepressant', 'prescription'), 1),
#  (('antidepressant', 'psilocybin'), 1),
#  (('antidepressant', 'psychedelic'), 1),
#  (('antidepressant', 'steroids_and_hormones'), 1),
#  (('antidepressant', 'stimulant'), 1),
#  (('antidepressant', 'uncategorizable_listing'), 1),
#  (('benzodiazepines', 'kratom'), 1),
#  (('benzodiazepines', 'uncategorizable_listing'), 1),
#  (('cocaine', 'kratom'), 1),
#  (('dissociative', 'erectile_dysfunction'), 1),
#  (('dissociative', 'inhalants'), 1),
#  (('dissociative', 'kratom'), 1),
#  (('dissociative', 'psilocybin'), 1),
#  (('dissociative', 'psychedelic'), 1),
#  (('dissociative', 'steroids_and_hormones'), 1),
#  (('dissociative', 'uncategorizable_listing'), 1),
#  (('dmt', 'erectile_dysfunction'), 1),
#  (('dmt', 'inhalants'), 1),
#  (('dmt', 'kratom'), 1),
#  (('dmt', 'opioid'), 1),
#  (('dmt', 'opioid_treatment'), 1),
#  (('dmt', 'steroids_and_hormones'), 1),
#  (('dmt', 'uncategorizable_listing'), 1),
#  (('ecstasy', 'kratom'), 1),
#  (('erectile_dysfunction', 'fentanyl'), 1),
#  (('erectile_dysfunction', 'inhalants'), 1),
#  (('erectile_dysfunction', 'kratom'), 1),
#  (('erectile_dysfunction', 'opioid_treatment'), 1),
#  (('erectile_dysfunction', 'prescription'), 1),
#  (('erectile_dysfunction', 'uncategorizable_listing'), 1),
#  (('fentanyl', 'inhalants'), 1),
#  (('fentanyl', 'kratom'), 1),
#  (('fentanyl', 'opioid_treatment'), 1),
#  (('fentanyl', 'prescription'), 1),
#  (('fentanyl', 'psychedelic'), 1),
#  (('fentanyl', 'steroids_and_hormones'), 1),
#  (('fentanyl', 'uncategorizable_listing'), 1),
#  (('hashish', 'kratom'), 1),
#  (('hashish', 'uncategorizable_listing'), 1),
#  (('heroin', 'kratom'), 1),
#  (('heroin', 'steroids_and_hormones'), 1),
#  (('heroin', 'uncategorizable_listing'), 1),
#  (('inhalants', 'kratom'), 1),
#  (('inhalants', 'opioid'), 1),
#  (('inhalants', 'opioid_treatment'), 1),
#  (('inhalants', 'oxycodone'), 1),
#  (('inhalants', 'prescription'), 1),
#  (('inhalants', 'uncategorizable_listing'), 1),
#  (('ketamine', 'kratom'), 1),
#  (('kratom', 'lsd'), 1),
#  (('kratom', 'marijuana'), 1),
#  (('kratom', 'methamphetamine'), 1),
#  (('kratom', 'not_drugs'), 1),
#  (('kratom', 'opioid'), 1),
#  (('kratom', 'opioid_treatment'), 1),
#  (('kratom', 'oxycodone'), 1),
#  (('kratom', 'prescription'), 1),
#  (('kratom', 'psilocybin'), 1),
#  (('kratom', 'psychedelic'), 1),
#  (('kratom', 'steroids_and_hormones'), 1),
#  (('kratom', 'stimulant'), 1),
#  (('kratom', 'uncategorizable_listing'), 1),
#  (('lsd', 'uncategorizable_listing'), 1),
#  (('marijuana', 'uncategorizable_listing'), 1),
#  (('opioid', 'psilocybin'), 1),
#  (('opioid', 'psychedelic'), 1),
#  (('opioid', 'steroids_and_hormones'), 1),
#  (('opioid', 'uncategorizable_listing'), 1),
#  (('opioid_treatment', 'prescription'), 1),
#  (('opioid_treatment', 'steroids_and_hormones'), 1),
#  (('opioid_treatment', 'uncategorizable_listing'), 1),
#  (('oxycodone', 'uncategorizable_listing'), 1),
#  (('prescription', 'psilocybin'), 1),
#  (('prescription', 'steroids_and_hormones'), 1),
#  (('prescription', 'uncategorizable_listing'), 1),
#  (('psilocybin', 'uncategorizable_listing'), 1),
#  (('psychedelic', 'steroids_and_hormones'), 1),
#  (('psychedelic', 'uncategorizable_listing'), 1),
#  (('steroids_and_hormones', 'uncategorizable_listing'), 1)]

# %%
market_co = pd.DataFrame(most_common)

# %%
#Export as csv
#market_co.to_csv('market_co.csv')

# %%
#saving in a file
import pickle
file=open('market_co' , 'wb')
pickle.dump(market_co, file)
file.close()
