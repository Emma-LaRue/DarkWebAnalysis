# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import compress
import math

# %%
product_descriptions = pd.read_csv('product_rating_modified.txt', header = None, sep = '\', \'', engine = 'python')

# Remove leading ' from first column
temp = [string[1:] for string in product_descriptions.iloc[:,0]]
product_descriptions.iloc[:,0] = temp

# %%
product_descriptions.to_csv('check_dates.csv')

# %%
product_descriptions.shape
# Out:
# (119934, 16)

# %%
product_descriptions.head()
# Out:
#      0   1     2                3        4    5   \
# 0  1098   3  1927  HeinekenExpress  P*****d  5.0
# 1  1099   3  1927  HeinekenExpress  B*****u  5.0
# 2  1100   3  1927  HeinekenExpress  z*****d  5.0
# 3  1101   3  1927  HeinekenExpress  b*****4  5.0
# 4  1102   3  1927  HeinekenExpress  K*****z  5.0
#
#                                                   6               7    8   \
# 0     As always a good product at an excellent price  20190102000000 -1.0
# 1                                No feedback comment  20181217000000 -1.0
# 2                                       Thank y bro   20181217000000 -1.0
# 3  Seems pretty nice, weighed 1g and got a free p...  20181216000000 -1.0
# 4  I just now saw your return policy says you don...  20181211000000 -1.0
#
#       9    10  11  12    13           14  \
# 0  33.21 -1.0  -1  -1  4410  1162_88_173
# 1  13.06 -1.0  -1  -1  4410  1162_88_173
# 2  12.90 -1.0  -1  -1  4410  1162_88_173
# 3  12.88 -1.0  -1  -1  4410  1162_88_173
# 4  50.44 -1.0  -1  -1  4410  1162_88_173
#
#                                                   15
# 0  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 1  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 2  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 3  ? MDMA very high QUALITY 87%?The Best MDMA for...
# 4  ? MDMA very high QUALITY 87%?The Best MDMA for...
