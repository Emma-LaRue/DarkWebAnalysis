# %% [markdown]
# # Reading in file and converting timestamps

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import compress

from datetime import datetime
from dateutil.parser import parse

import math
import os
import copy

# %%
# Reading the text file
product_descriptions = pd.read_csv('product_rating_modified.txt', header = None, sep = '\', \'', engine = 'python')
product_descriptions.columns = ['trans_id', 'mkt_id', 'vendor_id','vendor_name', 'buyer_name', \
                                'rating', 'comment', 'date', 'bitcoin_amt', 'USD', 'EUR', \
                                'buyer_#_orders', 'buyer_value_orders', 'product_id', 'product_mkt_id', 'product_title']

# %%
product_descriptions[product_descriptions.iloc[:,11]!=-1]
# Out:
#        trans_id  mkt_id  vendor_id                       vendor_name  \
# 2826      '3924       5       2647  eee099338c88f65006f24063ff3aca46
# 2827      '3925       5       2647  eee099338c88f65006f24063ff3aca46
# 2828      '3926       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2829      '3927       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2830      '3928       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2831      '3929       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2832      '3930       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2833      '3931       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2834      '3932       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2835      '3933       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2836      '3934       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2837      '3935       5       2651  ecbadce01a4cb2bf425a2b70548f240a
# 2838      '3936       5       2651  ecbadce01a4cb2bf425a2b70548f240a
# 2839      '3937       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2840      '3938       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2841      '3939       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2842      '3940       5       2677  3f82a4711140ba1ecaae4263b7b53f86
# 2843      '3941       5       2677  3f82a4711140ba1ecaae4263b7b53f86
# 2844      '3942       5       2697  7c088fa28e105d71e2cd49933edddc04
# 2845      '3943       5       2698  f264a3576de317fd0cb13687ebfa2933
# 2846      '3944       5       2698  f264a3576de317fd0cb13687ebfa2933
# 2847      '3945       5       2698  f264a3576de317fd0cb13687ebfa2933
# 2848      '3946       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2849      '3947       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 2850      '3948       5       2711  69ac25b0fd39bac003179d164050b253
# 2851      '3949       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2852      '3950       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2853      '3951       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2854      '3952       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# 2855      '3953       5       2670  cd6ef672c2ff60a03fd009ec48602c0a
# ...         ...     ...        ...                               ...
# 111458  '112556       5       2805  8cbbe8be5c9aef66a501a1b25e17efb7
# 111459  '112557       5       2730  2fd5d8bb03a339a2ef44aeddf0213d40
# 111460  '112558       5       2730  2fd5d8bb03a339a2ef44aeddf0213d40
# 111461  '112559       5       2730  2fd5d8bb03a339a2ef44aeddf0213d40
# 111462  '112560       5       3421  b804ffc841d12bb2c4394b67eab34826
# 111463  '112561       5       3421  b804ffc841d12bb2c4394b67eab34826
# 111464  '112562       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111465  '112563       5       2939  bbf891b57ac700bf4ebbc71e83ad07d4
# 111466  '112564       5       2939  bbf891b57ac700bf4ebbc71e83ad07d4
# 111467  '112565       5       2939  bbf891b57ac700bf4ebbc71e83ad07d4
# 111468  '112566       5       2939  bbf891b57ac700bf4ebbc71e83ad07d4
# 111469  '112567       5       2826  b09f475c5da310c27f798bda73de4ba9
# 111470  '112568       5       2965  13cfec3fd4c96b8cb095a3c9f1c16265
# 111471  '112569       5       2965  13cfec3fd4c96b8cb095a3c9f1c16265
# 111472  '112570       5       2698  f264a3576de317fd0cb13687ebfa2933
# 111473  '112571       5       2698  f264a3576de317fd0cb13687ebfa2933
# 111474  '112572       5       2698  f264a3576de317fd0cb13687ebfa2933
# 111475  '112573       5       2698  f264a3576de317fd0cb13687ebfa2933
# 111476  '112574       5       2790  550d05ab240ec337038af814ff0de287
# 111477  '112575       5       2790  550d05ab240ec337038af814ff0de287
# 111478  '112576       5       2790  550d05ab240ec337038af814ff0de287
# 111479  '112577       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111480  '112578       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111481  '112579       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111482  '112580       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111483  '112581       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111484  '112582       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111485  '112583       5       2648  acc3ebb6a498d7b138f3242e235cf65e
# 111486  '112584       5       2721  a959c5358054230efa213c5104bd63ef
# 111487  '112585       5       2721  a959c5358054230efa213c5104bd63ef
#
#        buyer_name  rating                                            comment  \
# 2826       d***e      5.0  FFT best vendor dealt with, professional and a...
# 2827       r***9      5.0                        Great vendor and products.
# 2828       s***h      5.0                                  No message leaved
# 2829       v***i      5.0  Best shop is here! Delivery always fast and st...
# 2830       v***i      5.0  Best quality ever! \nFastest delivery, Super s...
# 2831       A***9      5.0                  Very high quality K, good stealth
# 2832       v***i      5.0  Best Vendor Ever!\nGreat Ketamine quality, sup...
# 2833       v***i      0.0  ordered 10g - it\'s never arrived, vendor agre...
# 2834       T***2      5.0                                                TOP
# 2835       T***g      5.0           All good.  Quality vendor - RECOMMENDED.
# 2836       T***g      5.0                       Superb vendor - RECOMMENDED.
# 2837       c***z      5.0                                  No message leaved
# 2838       s***2      5.0  Great seller++++Always delivers a top product ...
# 2839       W***1      5.0     perfect, this vendor takes care of its clients
# 2840       W***1      5.0                       perfect shipping and product
# 2841       d***r      5.0                                                thx
# 2842       b***b      5.0                  Finally arrived !!! Thank you :-)
# 2843       o***q      5.0  Item as described, fast shipping, excellent co...
# 2844       n***1      5.0                                   GOOD! THANK YOU!
# 2845       p***7      5.0  nice dope..very professional. trust gained. I\...
# 2846       8***7      5.0              Fast delivery and good stuff! Thanks
# 2847       u***m      5.0  Arrived fairly quickly.A lot of vendors will p...
# 2848       W***1      5.0      4 days in EU. perfect stealth and a nice gift
# 2849       W***1      5.0  3 days in EU, super stealth. Will definetely c...
# 2850       t***3      5.0  18 days in France\nvery nice and understanding...
# 2851       H***e      5.0                        Fast delivery, many thanks.
# 2852       m***a      5.0                                  No message leaved
# 2853       i***u      5.0                                  No message leaved
# 2854       i***u      5.0                                  No message leaved
# 2855       T***S      5.0  A+++++++++++++++  GREAT VENDOR YOU CAN TRUST M...
# ...           ...     ...                                                ...
# 111458     p***r      5.0  Great product as always better stealth Started...
# 111459     n***y      5.0                                    As always 10/10
# 111460     B***a      5.0                                               A+++
# 111461     s***e      5.0  known this vendor since alphabay very good sel...
# 111462     p***3      5.0  Vendor is great at getting you the best produc...
# 111463     p***3      5.0  Awesome vendor! Has great product and communic...
# 111464     v***i      5.0  The best! New drug, will try soon. But this sh...
# 111465     G***p      5.0  today arrived Fast delivery excellent quality ...
# 111466     t***0      5.0                                               good
# 111467     k***9      5.0  Really nice gear, smooth on your nose, good hi...
# 111468     d***k      5.0  Arrived today in perfect condition. Good quali...
# 111469     j***k      5.0                   Perfect!\nKeep up the good work!
# 111470     i***y      5.0                         pacakage seized by customs
# 111471     c***5      5.0  Yeah this guy is my new dude. Fast on answerin...
# 111472     r***d      0.0  bad vendor not redpond at the message and orde...
# 111473     n***1      5.0  very good, very strong. thanks...\n\nbe carefu...
# 111474     n***1      5.0                                  No message leaved
# 111475     m***s      5.0  I can confirm this is the same Dutch Factory a...
# 111476     a***6      5.0                                   best vendor A+++
# 111477     G***p      5.0  today arrived Fast delivery excellent quality ...
# 111478     S***8      5.0  Received order with planned delay!\nQuality of...
# 111479     k***9      5.0                                  No message leaved
# 111480     t***s      5.0  Great product and great custom service,i-ve ha...
# 111481     r***e      5.0  Fast shipping. Havnt tried quality of the prod...
# 111482     t***s      5.0                        Great quality ,great price
# 111483     w***e      5.0                                  No message leaved
# 111484     P***m      5.0                                  No message leaved
# 111485     b***y      5.0     promptly delivered, top class service as usual
# 111486     s***f      5.0  THE BEST PRODUCT IN THE BEST PACKAGE\nVERY FAS...
# 111487     s***f      5.0  The best seller of darknet\nA very good produc...
#
#                   date  bitcoin_amt  USD       EUR  buyer_#_orders  \
# 2826    20180411154023         -1.0 -1.0  12555.60               1
# 2827    20180106003052         -1.0 -1.0    346.36               1
# 2828    20181007144938         -1.0 -1.0   5920.76              23
# 2829    20180830122846         -1.0 -1.0  11594.10              56
# 2830    20180806051408         -1.0 -1.0   8537.35              56
# 2831    20180628125023         -1.0 -1.0     94.40               6
# 2832    20180525161910         -1.0 -1.0     93.41              56
# 2833    20181025120606         -1.0 -1.0  19432.10              56
# 2834    20180607171603         -1.0 -1.0    180.79              24
# 2835    20180531142437         -1.0 -1.0    184.06              87
# 2836    20180524122106         -1.0 -1.0    165.47              87
# 2837    20180505201220         -1.0 -1.0    585.85               4
# 2838    20181119123022         -1.0 -1.0    105.84               1
# 2839    20181215213822         -1.0 -1.0     38.54              26
# 2840    20181215213512         -1.0 -1.0     35.24              26
# 2841    20180517181912         -1.0 -1.0     37.74               3
# 2842    20181128211445         -1.0 -1.0    207.91              26
# 2843    20181007233200         -1.0 -1.0   1284.63               5
# 2844    20181015115812         -1.0 -1.0     13.82              18
# 2845    20180503155850         -1.0 -1.0    100.85              12
# 2846    20180306165127         -1.0 -1.0     85.91               5
# 2847    20180126132027         -1.0 -1.0     83.72              43
# 2848    20181217120004         -1.0 -1.0     52.26              26
# 2849    20181120145738         -1.0 -1.0     75.66              26
# 2850    20180227120411         -1.0 -1.0     37.44               6
# 2851    20181023092141         -1.0 -1.0     65.21               8
# 2852    20181019110108         -1.0 -1.0     64.63              14
# 2853    20180910143231         -1.0 -1.0     58.23              10
# 2854    20180602104608         -1.0 -1.0     59.48              10
# 2855    20180525205959         -1.0 -1.0     29.02               8
# ...                ...          ...  ...       ...             ...
# 111458  20180316110053         -1.0 -1.0    758.90               8
# 111459  20180710182438         -1.0 -1.0    130.55               7
# 111460  20180323215341         -1.0 -1.0    138.15               3
# 111461  20180124210336         -1.0 -1.0    142.60               5
# 111462  20180517161544         -1.0 -1.0    133.23              35
# 111463  20180504200627         -1.0 -1.0    166.36              35
# 111464  20180716090049         -1.0 -1.0   3596.12              58
# 111465  20181011113233         -1.0 -1.0      3.60               5
# 111466  20180821112149         -1.0 -1.0      2.96               4
# 111467  20180817075550         -1.0 -1.0      3.15              40
# 111468  20180425201141         -1.0 -1.0      3.82              11
# 111469  20180817205616         -1.0 -1.0     32.77               4
# 111470  20171221185727         -1.0 -1.0     55.01               0
# 111471  20171021042634         -1.0 -1.0     47.97               1
# 111472  20181128091731         -1.0 -1.0     25.64              39
# 111473  20181028145532         -1.0 -1.0     40.52              18
# 111474  20181006171752         -1.0 -1.0    119.27              18
# 111475  20171113164037         -1.0 -1.0     43.75               5
# 111476  20181220114111         -1.0 -1.0     15.27              27
# 111477  20181011113323         -1.0 -1.0     10.74               5
# 111478  20190111063206         -1.0 -1.0     73.85               5
# 111479  20181102112655         -1.0 -1.0     20.39               2
# 111480  20180326220001         -1.0 -1.0     14.02              13
# 111481  20181030155457         -1.0 -1.0     32.74               3
# 111482  20180818085615         -1.0 -1.0     29.92              13
# 111483  20180727090215         -1.0 -1.0     40.82               3
# 111484  20180425074727         -1.0 -1.0     75.56              27
# 111485  20181021005351         -1.0 -1.0    246.84              11
# 111486  20180924200306         -1.0 -1.0   1406.72              11
# 111487  20180830200112         -1.0 -1.0   1365.65              11
#
#         buyer_value_orders  product_id product_mkt_id  \
# 2826                    -1        8193   0096c8e30e2b
# 2827                    -1        8193   0096c8e30e2b
# 2828                    -1        8198   b52a9a2cf312
# 2829                    -1        8200   68989469407d
# 2830                    -1        8200   68989469407d
# 2831                    -1        8200   68989469407d
# 2832                    -1        8200   68989469407d
# 2833                    -1        8202   569442a1d6b2
# 2834                    -1        8202   569442a1d6b2
# 2835                    -1        8202   569442a1d6b2
# 2836                    -1        8202   569442a1d6b2
# 2837                    -1        8211   fb68444e1fa4
# 2838                    -1        8213   66eabc2a8eb4
# 2839                    -1        8335   fda755133c3a
# 2840                    -1        8335   fda755133c3a
# 2841                    -1        8335   fda755133c3a
# 2842                    -1        8396   17a6ba4bf661
# 2843                    -1        8396   17a6ba4bf661
# 2844                    -1        8528   8cc51b3f1ecb
# 2845                    -1        8536   0e0ebb112365
# 2846                    -1        8536   0e0ebb112365
# 2847                    -1        8536   0e0ebb112365
# 2848                    -1        8556   44762e00261b
# 2849                    -1        8556   44762e00261b
# 2850                    -1        8623   3b586b6e6566
# 2851                    -1        8631   a505e85e38cf
# 2852                    -1        8631   a505e85e38cf
# 2853                    -1        8631   a505e85e38cf
# 2854                    -1        8631   a505e85e38cf
# 2855                    -1        8631   a505e85e38cf
# ...                    ...         ...            ...
# 111458                  -1        9946   9eb486848c96
# 111459                  -1       18496   cbac9bca6fae
# 111460                  -1       18496   cbac9bca6fae
# 111461                  -1       18496   cbac9bca6fae
# 111462                  -1       13872   9e43c6abb28d
# 111463                  -1       13872   9e43c6abb28d
# 111464                  -1       18192   a876f8e069c0
# 111465                  -1       11387   e83f8157aaca
# 111466                  -1       11387   e83f8157aaca
# 111467                  -1       11387   e83f8157aaca
# 111468                  -1       11387   e83f8157aaca
# 111469                  -1       11323   f8ed18fe59dc
# 111470                  -1       11999   67b78e20b51c
# 111471                  -1       11999   67b78e20b51c
# 111472                  -1       17353   0fcc841aae8d
# 111473                  -1       17353   0fcc841aae8d
# 111474                  -1       17353   0fcc841aae8d
# 111475                  -1       17353   0fcc841aae8d
# 111476                  -1       15827   033fd2a9fccc
# 111477                  -1       15827   033fd2a9fccc
# 111478                  -1       15829   10f2bc85f718
# 111479                  -1       16698   c2eeab2a5bfb
# 111480                  -1       16698   c2eeab2a5bfb
# 111481                  -1       16700   f1e3827c8d5e
# 111482                  -1       16700   f1e3827c8d5e
# 111483                  -1       16700   f1e3827c8d5e
# 111484                  -1       16700   f1e3827c8d5e
# 111485                  -1       16703   8a344bf5b81c
# 111486                  -1       15587   02aa1d86f25e
# 111487                  -1       15587   02aa1d86f25e
#
#                                             product_title
# 2826            *LIMITED* 7 grams CRAZY CARTEL COKE (CCC)
# 2827            *LIMITED* 7 grams CRAZY CARTEL COKE (CCC)
# 2828    ? 1g Ketamine High Quality 87% ? EC LABTESTED ...
# 2829    ?  5g Ketamine High Quality 87% ?EC LABTESTED ...
# 2830    ?  5g Ketamine High Quality 87% ?EC LABTESTED ...
# 2831    ?  5g Ketamine High Quality 87% ?EC LABTESTED ...
# 2832    ?  5g Ketamine High Quality 87% ?EC LABTESTED ...
# 2833    ?  10g Ketamine High Quality 87% ?  EC LABTEST...
# 2834    ?  10g Ketamine High Quality 87% ?  EC LABTEST...
# 2835    ?  10g Ketamine High Quality 87% ?  EC LABTEST...
# 2836    ?  10g Ketamine High Quality 87% ?  EC LABTEST...
# 2837                           Oxycotin  caps   1 x 20 mg
# 2838             Oxycotin  caps   1 x 20 mg 15 % DISCOUNT
# 2839              Pregabalin Zentiva 300 mg x 28 Capsules
# 2840              Pregabalin Zentiva 300 mg x 28 Capsules
# 2841              Pregabalin Zentiva 300 mg x 28 Capsules
# 2842               CARFENTANIL solution - 20ml (100ug/ml)
# 2843               CARFENTANIL solution - 20ml (100ug/ml)
# 2844                                    RIF KETAMA POLLEN
# 2845                    ? 2G PURE Heroin #3 TOP-QUALiTY ?
# 2846                    ? 2G PURE Heroin #3 TOP-QUALiTY ?
# 2847                    ? 2G PURE Heroin #3 TOP-QUALiTY ?
# 2848                      ?1x Oxycodone  80MG \'Sandoz\'?
# 2849                      ?1x Oxycodone  80MG \'Sandoz\'?
# 2850                               1g coke Social cocaine
# 2851       Genuine MSJ Diazepam 10mg Valium x 100 Tablets
# 2852       Genuine MSJ Diazepam 10mg Valium x 100 Tablets
# 2853       Genuine MSJ Diazepam 10mg Valium x 100 Tablets
# 2854       Genuine MSJ Diazepam 10mg Valium x 100 Tablets
# 2855       Genuine MSJ Diazepam 10mg Valium x 100 Tablets
# ...                                                   ...
# 111458                       ROHYPNOL 2MG (FLUNITRAZEPAM)
# 111459                                   10g A-Grade Weed
# 111460                                   10g A-Grade Weed
# 111461                                   10g A-Grade Weed
# 111462             1.0 Gram of FIRE Heroin #4 (LONG LEGS)
# 111463             1.0 Gram of FIRE Heroin #4 (LONG LEGS)
# 111464                    ?5x 4-FA / 4-fmp Capsule 200mg?
# 111465  £2.40 INC P&P SAMPLE 0.1G FLAKE! MUSTTRY LISTI...
# 111466  £2.40 INC P&P SAMPLE 0.1G FLAKE! MUSTTRY LISTI...
# 111467  £2.40 INC P&P SAMPLE 0.1G FLAKE! MUSTTRY LISTI...
# 111468  £2.40 INC P&P SAMPLE 0.1G FLAKE! MUSTTRY LISTI...
# 111469                 5g \"AK-47\" 12%THC *100% Organic*
# 111470               FC Barca pills (Purple) 25Pcs./270mg
# 111471               FC Barca pills (Purple) 25Pcs./270mg
# 111472                  ? 1G PURE Heroin #3 TOP-QUALiTY ?
# 111473                  ? 1G PURE Heroin #3 TOP-QUALiTY ?
# 111474                  ? 1G PURE Heroin #3 TOP-QUALiTY ?
# 111475                  ? 1G PURE Heroin #3 TOP-QUALiTY ?
# 111476         1 gr. Premium Blond Hash (Ketama, Morocco)
# 111477         1 gr. Premium Blond Hash (Ketama, Morocco)
# 111478        10 gr. Premium Blond Hash (Ketama, Morocco)
# 111479                             ? 5 x Maya LSD 180ug ?
# 111480                             ? 5 x Maya LSD 180ug ?
# 111481                            ? 10 x Maya LSD 180ug ?
# 111482                            ? 10 x Maya LSD 180ug ?
# 111483                            ? 10 x Maya LSD 180ug ?
# 111484                            ? 10 x Maya LSD 180ug ?
# 111485                           ? 100 x Maya LSD 180ug ?
# 111486                                      100G KETAMINE
# 111487                                      100G KETAMINE
#
# [6007 rows x 16 columns]

# %%
# Only get transactions in Market 1
product_descriptions = product_descriptions[product_descriptions.iloc[:,1] == 1]
# product_descriptions = product_descriptions[product_descriptions.iloc[:,1] == 6]

# %%
product_descriptions.groupby('mkt_id').count()
# Out:
#         trans_id  vendor_id  vendor_name  buyer_name  rating  comment   date  \
# mkt_id
# 1          92388      92388        92388       92388   92388    92388  92388
#
#         bitcoin_amt    USD    EUR  buyer_#_orders  buyer_value_orders  \
# mkt_id
# 1             92388  92388  92388           92388               92388
#
#         product_id  product_mkt_id  product_title
# mkt_id
# 1            92388           92388          92388

# %%
product_descriptions.shape
# Out:
# (92388, 16)

# %%
# Function to convert numeric time to datetime object
def parseDate(raw_date, pattern = '%Y%m%d%H%M%S'):
    string_date = str(raw_date)
    return(datetime.strptime(string_date, pattern))

# Parse the dates, and place in new column
product_descriptions['dates'] = product_descriptions.iloc[:,7].apply(parseDate)

# %% [markdown]
# # Tokenizing Product Description

# %%
import spacy
from spacy.lang.en import English
parser = English()

# %%
# Function to tokenize titles
def tokenize_1(title):
    tokens = parser(title.lower())
    tokens = [token.orth_ for token in tokens if not token.orth_.isspace()]
    return(tokens)

# %%
# Apply tokenizer to the titles in the dataframe
product_descriptions['tokenized_titles'] = product_descriptions.iloc[:,15].apply(tokenize_1)

# %%
# Alternative tokenizer
special_char =['`','\'','=','-','~','!','@','#','$','^','&','*','(',')','_','+','[',']','{','}',';','\\',':','|','<','<','>','?','//']

def remove_special_char(string):
    for char in special_char:
        string = string.replace(char,' ')
    return(string)

def tokenize(string):
    return remove_special_char(string).split()

# %% [markdown]
# # Categorize drugs

# %%
import drugLookup

# %% [markdown]
# Get list of slang phrases that are multiple words

# %%
# Load drugs dictionary
drugs_dict = drugLookup.get_drugs_dict()

complete_multi_word_list = []

drug_index = 0
#For loop that gets all the synonyms of drugs with more than one word
for drug in drugs_dict.keys():
    slang_words = drugs_dict[drug]
    multi_word_list = []
    for slang_word in slang_words:
        if ' ' in slang_word:
            multi_word_list.append(slang_word)
    complete_multi_word_list.append(multi_word_list)

# %%
# Create multi_word dictionary
drug_cats = list(drugs_dict.keys())
multi_drug_dict = dict(zip(drug_cats, complete_multi_word_list))

# %%
# Load dictionary of drugs
drugs_dict = drugLookup.get_drugs_dict()


# Get list of possible drugs for each listing
def categorize_listing(title_set):
    #     Function takes in set of two: first entry is raw_title, second is tokenized_title
    possible_drugs = []
    list_title_set = list(title_set)
    raw_title = list_title_set[0]
    tokenized_title = list_title_set[1]
    for drug in drugs_dict.keys():
        if any(token in drugs_dict[drug]
               for token in tokenized_title):  # uses tokenization
            possible_drugs.append(drug)
        if any(multi_word in raw_title.lower()
               for multi_word in multi_drug_dict[drug]):
            possible_drugs.append(drug)
    return possible_drugs

# %%
# Categorize each listing
product_descriptions['drug_prediction'] = product_descriptions.iloc[:,[15,17]].apply(categorize_listing, axis = 1)

# %% [markdown]
# # Remove bad dates

# %%
# Look at distribution of dates
product_descriptions['dates'].groupby(product_descriptions["dates"].dt.year).count().plot(kind='bar')
plt.show()
product_descriptions['dates'].groupby(product_descriptions["dates"].dt.year).count()
# Out:
# dates
# 1969     2457
# 1970        2
# 2017       25
# 2018    84014
# 2019     5890
# Name: dates, dtype: int64

# %%
# Plot the 2019 dates
after_2019 = product_descriptions['dates'] > datetime(2019,1,1)
after_2019_df = product_descriptions[after_2019]
after_2019_df['dates'].groupby(after_2019_df["dates"].dt.month).count().plot(kind='bar')
plt.show()

after_2019_df['dates'].groupby(after_2019_df["dates"].dt.month).count()

#after_2019
# Out:
# dates
# 1    5890
# Name: dates, dtype: int64

# %%
# Plot the 2017 dates
before_2018 = product_descriptions['dates'] < datetime(2018,1,1)
after_2016 = product_descriptions['dates'] > datetime(2016,12,31)
in_2017_df = product_descriptions[after_2016 & before_2018]
in_2017_df['dates'].groupby(in_2017_df["dates"].dt.month).count().plot(kind='bar')
plt.ylabel('Number of Listings')
plt.xlabel('Month')
plt.show()

# %%
# Filter out the 1969/1970/2019 dates
# good_dates = product_desci
before_2019 = product_descriptions['dates'] < datetime(2019,2,1)
after_2017 = product_descriptions['dates'] > datetime(2018,4,1)
df = product_descriptions[before_2019 & after_2017]

# %%
product_descriptions.head()
# Out:
#      trans_id  mkt_id  vendor_id     vendor_name buyer_name  rating  \
# 9430   '10528       1        590        superclr      #####     5.0
# 9431   '10529       1        590        superclr      #####     5.0
# 9432   '10530       1       1013  REAL_MEGASTORE      #####     5.0
# 9433   '10531       1       1013  REAL_MEGASTORE      #####     5.0
# 9434   '10532       1         92      OnionKings      #####     5.0
#
#                                                 comment            date  \
# 9430  Vendor did a great job 5 across the board exce...  20181102064301
# 9431                                              GREAT  20181110064301
# 9432                           Enter your comments here  20181227064306
# 9433                           Enter your comments here  20181227064306
# 9434                                       Kanon. 5/5/5  19691231190000
#
#       bitcoin_amt      USD  EUR  buyer_#_orders  buyer_value_orders  \
# 9430         -1.0  416.000 -1.0              -1                  -1
# 9431         -1.0  416.000 -1.0              -1                  -1
# 9432         -1.0    3.120 -1.0              -1                  -1
# 9433         -1.0    3.120 -1.0              -1                  -1
# 9434         -1.0  109.119 -1.0              -1                  -1
#
#       product_id product_mkt_id                                product_title  \
# 9430         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9431         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9432         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9433         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9434         112   812534.21917     Rivotril 2mg från apotek (Roche) [100st]
#
#                    dates                                   tokenized_titles  \
# 9430 2018-11-02 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9431 2018-11-10 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9432 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9433 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9434 1969-12-31 19:00:00  [rivotril, 2, mg, från, apotek, (, roche, ), [...
#
#         drug_prediction
# 9430           [heroin]
# 9431           [heroin]
# 9432                 []
# 9433                 []
# 9434  [benzodiazepines]

# %%
# Plot 2018 dates
df['dates'].groupby(df["dates"].dt.month).count().plot(kind='bar')
plt.show()

monthly_listings = df['dates'].groupby(df["dates"].dt.month).count()
total_listings = sum(df['dates'].groupby(df["dates"].dt.month).count())

print(monthly_listings)
total_listings
#percentage_of_listings =
# Out:
# dates
# 1      5890
# 4      2103
# 5      4164
# 6      4316
# 7      4786
# 8      8382
# 9      9607
# 10    13225
# 11    16497
# 12    20872
# Name: dates, dtype: int64
# 89842

# %%
df.shape
df.head()
# Out:
#      trans_id  mkt_id  vendor_id     vendor_name buyer_name  rating  \
# 9430   '10528       1        590        superclr      #####     5.0
# 9431   '10529       1        590        superclr      #####     5.0
# 9432   '10530       1       1013  REAL_MEGASTORE      #####     5.0
# 9433   '10531       1       1013  REAL_MEGASTORE      #####     5.0
# 9435   '10533       1         92      OnionKings      #####     5.0
#
#                                                 comment            date  \
# 9430  Vendor did a great job 5 across the board exce...  20181102064301
# 9431                                              GREAT  20181110064301
# 9432                           Enter your comments here  20181227064306
# 9433                           Enter your comments here  20181227064306
# 9435        Toppklass!! Snabb leverans. Allt perfekt!!!  20181221064311
#
#       bitcoin_amt      USD  EUR  buyer_#_orders  buyer_value_orders  \
# 9430         -1.0  416.000 -1.0              -1                  -1
# 9431         -1.0  416.000 -1.0              -1                  -1
# 9432         -1.0    3.120 -1.0              -1                  -1
# 9433         -1.0    3.120 -1.0              -1                  -1
# 9435         -1.0  109.119 -1.0              -1                  -1
#
#       product_id product_mkt_id                                product_title  \
# 9430         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9431         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9432         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9433         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9435         112   812534.21917     Rivotril 2mg från apotek (Roche) [100st]
#
#                    dates                                   tokenized_titles  \
# 9430 2018-11-02 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9431 2018-11-10 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9432 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9433 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9435 2018-12-21 06:43:11  [rivotril, 2, mg, från, apotek, (, roche, ), [...
#
#         drug_prediction
# 9430           [heroin]
# 9431           [heroin]
# 9432                 []
# 9433                 []
# 9435  [benzodiazepines]

# %%
df = product_descriptions
df.columns
# Out:
# Index(['trans_id', 'mkt_id', 'vendor_id', 'vendor_name', 'buyer_name',
#        'rating', 'comment', 'date', 'bitcoin_amt', 'USD', 'EUR',
#        'buyer_#_orders', 'buyer_value_orders', 'product_id', 'product_mkt_id',
#        'product_title', 'dates', 'tokenized_titles', 'drug_prediction'],
#       dtype='object')

# %%
df.head()
# Out:
#      trans_id  mkt_id  vendor_id     vendor_name buyer_name  rating  \
# 9430   '10528       1        590        superclr      #####     5.0
# 9431   '10529       1        590        superclr      #####     5.0
# 9432   '10530       1       1013  REAL_MEGASTORE      #####     5.0
# 9433   '10531       1       1013  REAL_MEGASTORE      #####     5.0
# 9434   '10532       1         92      OnionKings      #####     5.0
#
#                                                 comment            date  \
# 9430  Vendor did a great job 5 across the board exce...  20181102064301
# 9431                                              GREAT  20181110064301
# 9432                           Enter your comments here  20181227064306
# 9433                           Enter your comments here  20181227064306
# 9434                                       Kanon. 5/5/5  19691231190000
#
#       bitcoin_amt      USD  EUR  buyer_#_orders  buyer_value_orders  \
# 9430         -1.0  416.000 -1.0              -1                  -1
# 9431         -1.0  416.000 -1.0              -1                  -1
# 9432         -1.0    3.120 -1.0              -1                  -1
# 9433         -1.0    3.120 -1.0              -1                  -1
# 9434         -1.0  109.119 -1.0              -1                  -1
#
#       product_id product_mkt_id                                product_title  \
# 9430         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9431         110   714882.72220  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN
# 9432         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9433         111  141915.284891                         ?CRAVETV.CA? PREMIUM
# 9434         112   812534.21917     Rivotril 2mg från apotek (Roche) [100st]
#
#                    dates                                   tokenized_titles  \
# 9430 2018-11-02 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9431 2018-11-10 06:43:01  [5, grams, grade, aaa+, cartel, tan, powder, h...
# 9432 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9433 2018-12-27 06:43:06                        [?, cravetv.ca, ?, premium]
# 9434 1969-12-31 19:00:00  [rivotril, 2, mg, från, apotek, (, roche, ), [...
#
#         drug_prediction
# 9430           [heroin]
# 9431           [heroin]
# 9432                 []
# 9433                 []
# 9434  [benzodiazepines]

# %%
# Get subset of columns that we care about
# drug_data = copy.deepcopy(df.iloc[:,[0,2,3,15,16,18]])
drug_data = copy.deepcopy(df.loc[:,['trans_id','vendor_id','vendor_name','bitcoin_amt','USD',
                                    'product_title','dates', 'drug_prediction']])
drug_data.columns = ['transaction_id','vendor_id','vendor_name', 'bitcoin_amt','USD',
                     'product_description','date', 'drug_prediction']
# drug_data.columns = ['transaction_id','vendor_id','vendor_name', 'product_description','date', 'drug_prediction']

# %%
drug_data.head()
# Out:
#      transaction_id  vendor_id     vendor_name  bitcoin_amt      USD  \
# 9430         '10528        590        superclr         -1.0  416.000
# 9431         '10529        590        superclr         -1.0  416.000
# 9432         '10530       1013  REAL_MEGASTORE         -1.0    3.120
# 9433         '10531       1013  REAL_MEGASTORE         -1.0    3.120
# 9434         '10532         92      OnionKings         -1.0  109.119
#
#                               product_description                date  \
# 9430  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN 2018-11-02 06:43:01
# 9431  5 GRAMS GRADE AAA+ CARTEL TAN POWDER HEROIN 2018-11-10 06:43:01
# 9432                         ?CRAVETV.CA? PREMIUM 2018-12-27 06:43:06
# 9433                         ?CRAVETV.CA? PREMIUM 2018-12-27 06:43:06
# 9434     Rivotril 2mg från apotek (Roche) [100st] 1969-12-31 19:00:00
#
#         drug_prediction
# 9430           [heroin]
# 9431           [heroin]
# 9432                 []
# 9433                 []
# 9434  [benzodiazepines]

# %% [markdown]
# Pickle the dataframe (so that it can be used in another file)

# %%
import pickle
file = open('drug_data','wb')
pickle.dump(drug_data, file)
file.close()

# %% [markdown]
# # Remove not_drugs

# %%
def isDrug(categoryList):
    return('not_drugs' not in categoryList)
row_is_drug = drug_data['drug_prediction'].apply(isDrug)
drug_data = drug_data[row_is_drug]

# %% [markdown]
# # Count number of assigned categories for each review

# %%
# Count categories for each listing
print('Count number of labels for each listing:')
print(drug_data['drug_prediction'].apply(len).groupby(drug_data['drug_prediction'].apply(len)).count())
# Out:
# Count number of labels for each listing:
# drug_prediction
# 0     7212
# 1    68378
# 2     6044
# 3      224
# Name: drug_prediction, dtype: int64

# %%
cond1 = drug_data['drug_prediction'].apply(len) != 1
problems = copy.deepcopy(drug_data[cond1])

# %%
problems.shape
problems.head()
# Out:
#      transaction_id  vendor_id     vendor_name  bitcoin_amt      USD  \
# 9432         '10530       1013  REAL_MEGASTORE         -1.0   3.1200
# 9433         '10531       1013  REAL_MEGASTORE         -1.0   3.1200
# 9453         '10551       1866      SweShrooms         -1.0  16.0657
# 9454         '10552       1866      SweShrooms         -1.0  16.0657
# 9455         '10553       1866      SweShrooms         -1.0  16.0657
#
#                                   product_description                date  \
# 9432                             ?CRAVETV.CA? PREMIUM 2018-12-27 06:43:06
# 9433                             ?CRAVETV.CA? PREMIUM 2018-12-27 06:43:06
# 9453  SweShrooms - Cubensis Mycelium (4 Strains) 1 st 2018-12-20 06:43:16
# 9454  SweShrooms - Cubensis Mycelium (4 Strains) 1 st 2018-12-23 06:43:16
# 9455  SweShrooms - Cubensis Mycelium (4 Strains) 1 st 2018-12-21 06:43:16
#
#               drug_prediction
# 9432                       []
# 9433                       []
# 9453  [marijuana, psilocybin]
# 9454  [marijuana, psilocybin]
# 9455  [marijuana, psilocybin]

# %%
problems.to_csv('problems.csv')

# %% [markdown]
# # Get reviews with only 1 category

# %%
# Get listings with fewer than 1 category
cond1 = drug_data['drug_prediction'].apply(len) < 2
cond2 = drug_data['drug_prediction'].apply(len) > 0
drug_df = copy.deepcopy(drug_data[cond1 & cond2])

# Get first string in one element list of strings
# Input: list of strings
def getFirst(mylist):
    return(mylist[0])
drug_df['drug_prediction'] = drug_df['drug_prediction'].apply(getFirst)

# %% [markdown]
# ##  Extract price information

# %%
from datetime import datetime
#bitcoin to USD file
btc_price = pd.read_csv('btc_data.csv')

# convert dates to datetime.date
btc_date = []
for date in btc_price.loc[:,'Date']:
    btc_date.append(datetime.strptime(date, '%m/%d/%Y').date())

# %%
# Function to convert BTC to USD
def btc_to_usd(df_row):
#     Function takes in a row of a Pandas dataframe (drug_df)
#     Returns: USD equivalent amount if amount can be converted; `None' otherwise
    btc_amt = df_row['bitcoin_amt']
    date = df_row['date'].date()
    if btc_amt != -1.0:
        if date in set(dict_btc.keys()):
            return(round(float(btc_amt * dict_btc[date]),2))
    else:
        return(df_row['USD'])

# %%
# Dictionary with conversion values (BTC to USD)
dict_btc = dict(zip(btc_date, btc_price['Open'])) # store the bitcoin price as dict

# Apply function to dataframe; i.e. convert bitcoin amount to USD
drug_df['USD'] = drug_df.apply(btc_to_usd, axis = 1)

# %%
drug_df.tail()
# Out:
#        transaction_id  vendor_id    vendor_name  bitcoin_amt    USD  \
# 119866        '120964        417  dare-devil666       0.0052  18.03
# 119867        '120965        417  dare-devil666       0.0052  25.01
# 119868        '120966        417  dare-devil666       0.0052  18.68
# 119869        '120967       3181    aKINDercare      -1.0000  80.60
# 119870        '120968       3181    aKINDercare      -1.0000  80.60
#
#                                      product_description                date  \
# 119866    10 Gram Speed Paste 76% Purity PINK PANTHER HQ 2018-12-11 14:29:43
# 119867    10 Gram Speed Paste 76% Purity PINK PANTHER HQ 2018-11-20 14:29:43
# 119868    10 Gram Speed Paste 76% Purity PINK PANTHER HQ 2018-12-10 14:29:43
# 119869  SALE!! SFV OG Cannabis Vape Oil | 50% THC | 10ml 2019-01-18 14:29:52
# 119870  SALE!! SFV OG Cannabis Vape Oil | 50% THC | 10ml 2019-01-17 14:29:52
#
#         drug_prediction
# 119866  methamphetamine
# 119867  methamphetamine
# 119868  methamphetamine
# 119869        marijuana
# 119870        marijuana

# %% [markdown]
# Pickle the dataframe (so that it can be used in another file)

# %%
import pickle
file = open('drug_df','wb')
pickle.dump(drug_df, file)
file.close()
